# %% [markdown]
# ## Data Cleaning & Profiling

# %%
import pandas as pd
import numpy as np

# Load the dataset
file_path = '/Users/ging/Documents/Data Analytics Course/GHG Emissions Worldwide/02 Data/Original Data/GHG_Emissions_World_Sector_Country.xlsx'
data = pd.read_excel(file_path)

# Initial profiling
missing_data = data.isnull().sum()
duplicates = data.duplicated().sum()

print("Missing Data:\n", missing_data)
print("\nDuplicates:", duplicates)

# Document missing data
missing_report = missing_data[missing_data > 0].to_dict()
print("\nMissing Data Report:", missing_report)

# Document duplicates
if duplicates > 0:
    data = data.drop_duplicates()
    print(f"{duplicates} duplicates removed. Remaining entries: {len(data)}")

# Profiling numerical columns
numerical_summary = data.describe()
print("\nNumerical Columns Summary:\n", numerical_summary)

# Check categorical columns for inconsistencies
categorical_columns = ['GHG', 'Sector', 'EDGAR Country Code', 'Country']
categorical_summary = {col: data[col].value_counts() for col in categorical_columns}
print("\nCategorical Columns Summary:\n", categorical_summary)

# Mixed-type columns and data types
data_types = data.dtypes
print("\nData Types:\n", data_types)

# Addressing missing data by averaging 5 years before and after for the country and sector
def fill_missing_data(row, year, data):
    sector = row['Sector']
    country = row['Country']
    start_year = max(1970, year - 5)
    end_year = min(2022, year + 5)
    
    relevant_years = list(range(start_year, end_year + 1))
    if year in relevant_years:
        relevant_years.remove(year)  # Remove the current year

    values = data[(data['Sector'] == sector) & 
                  (data['Country'] == country)][relevant_years].dropna()
    
    if not values.empty:
        return values.mean(axis=1).mean()  # Mean across the available years
    else:
        return np.nan

years = list(range(1970, 2023))
for year in years:
    col_name = str(year)
    if col_name in data.columns:
        data[col_name] = data.apply(
            lambda row: fill_missing_data(row, year, data) if pd.isnull(row[col_name]) else row[col_name], axis=1
        )

print("\nMissing data filled with the average of 5 years before and 5 years after for each country and sector.")

# Detecting and handling outliers (simple method using IQR)
def detect_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[col] < lower_bound) | (df[col] > upper_bound)]

outliers = {col: detect_outliers(data, col) for col in data.columns[4:]}

print("\nOutliers detected in each column:")
for col, outlier_df in outliers.items():
    print(f"{col}: {len(outlier_df)} outliers")

# Handling outliers (removing in this case)
for col in data.columns[4:]:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]

print("\nOutliers removed from the dataset.")
print("\nCleaned data shape:", data.shape)

# Save the cleaned data
output_file_path = '/Users/ging/Documents/Data Analytics Course/GHG Emissions Worldwide/02 Data/Prepared Data/GHG_Emissions_World_Sector_Country_Cleaned.xlsx'
data.to_excel(output_file_path, index=False)
print(f"\nCleaned data saved to {output_file_path}")

# Summary statistics as a simple table
summary_stats = data.describe().transpose()
print("\nSummary Statistics:")
print(summary_stats)

summary_stats_output_path = '/Users/ging/Documents/Data Analytics Course/GHG Emissions Worldwide/04 Analysis/Reports/Summary_Statistics.xlsx'
summary_stats.to_excel(summary_stats_output_path)
print(f"\nSummary statistics saved to {summary_stats_output_path}")
# Out:
# Missing Data:
#  GHG                     0
# Sector                  0
# EDGAR Country Code      0
# Country                 0
# 1970                  130
# 1971                  130
# 1972                  128
# 1973                  121
# 1974                  123
# 1975                  121
# 1976                  112
# 1977                  111
# 1978                  106
# 1979                  104
# 1980                  118
# count  4.693000e+03  4690.000000  4693.000000  4694.000000  4694.000000
# mean   1.116517e+01    11.206255    10.788900    11.303069    11.458466
# std    1.052893e+02   106.708875   106.420829   113.694539   114.975694
# min    2.180488e-09     0.000000     0.000000     0.000000     0.000000
# 25%    8.700372e-03     0.008971     0.008511     0.008714     0.008775
# 50%    1.442868e-01     0.147524     0.140740     0.144710     0.146934
# 75%    1.885781e+00     1.928050     1.855318     1.901821     1.910933
# max    5.071185e+03  5238.130847  5376.577978  5822.845160  5896.781595
#
# [8 rows x 53 columns]
#
# Categorical Columns Summary:
#  {'GHG': GHG
# GWP_100_AR5_N2O        1641
# GWP_100_AR5_CH4        1532
# CO2                    1449
# GWP_100_AR5_F-gases     156
# Name: count, dtype: int64, 'Sector': Sector
# Processes                670
# Transport                627
# Buildings                622
# Power Industry           621
# Industrial Combustion    618
# Fuel Exploitation        600
# Waste                    518
# Agriculture              502
# Name: count, dtype: int64, 'EDGAR Country Code': EDGAR Country Code
# TUR    25
# KOR    25
# GBR    25
# NZL    25
# GRC    25
#        ..
# ESH    16
# GIB    13
# FRO     9
# SEA     5
# AIR     4
# Name: count, Length: 210, dtype: int64, 'Country': Country
# Türkiye                   25
# South Korea               25
# United Kingdom            25
# New Zealand               25
# Greece                    25
#                           ..
# Western Sahara            16
# Gibraltar                 13
# Faroes                     9
# International Shipping     5
# International Aviation     4
# Name: count, Length: 210, dtype: int64}
#
# Data Types:
#  GHG                    object
# Sector                 object
# EDGAR Country Code     object
# Country                object
# 1970                  float64
# 1971                  float64
# 1972                  float64
# 1973                  float64
# 1974                  float64
# 1975                  float64
# 1976                  float64
# 1977                  float64
# 1978                  float64
# 1979                  float64
# 1980                  float64
# 1981                  float64
# 1982                  float64
# 1983                  float64
# 1984                  float64
# 1985                  float64
# 1986                  float64
# 1987                  float64
# 1988                  float64
# 1989                  float64
# 1990                  float64
# 1991                  float64
# 1992                  float64
# 1993                  float64
# 1994                  float64
# 1995                  float64
# 1996                  float64
# 1997                  float64
# 1998                  float64
# 1999                  float64
# 2000                  float64
# 2001                  float64
# 2002                  float64
# 2003                  float64
# 2004                  float64
# 2005                  float64
# 2006                  float64
# 2007                  float64
# 2008                  float64
# 2009                  float64
# 2010                  float64
# 2011                  float64
# 2012                  float64
# 2013                  float64
# 2014                  float64
# 2015                  float64
# 2016                  float64
# 2017                  float64
# 2018                  float64
# 2019                  float64
# 2020                  float64
# 2021                  float64
# 2022                  float64
# dtype: object
#
# Missing data filled with the average of 5 years before and 5 years after for each country and sector.
#
# Outliers detected in each column:
# 1970: 827 outliers
# 1971: 831 outliers
# 1972: 830 outliers
# 1973: 834 outliers
# 1974: 830 outliers
# 1975: 847 outliers
# 1976: 836 outliers
# 1977: 842 outliers
# 1978: 845 outliers
# 1979: 838 outliers
# 1980: 835 outliers
# 1981: 841 outliers
# 1982: 840 outliers
# 1983: 836 outliers
# 1984: 829 outliers
# 1985: 825 outliers
# 1986: 833 outliers
# 1987: 830 outliers
# 1988: 826 outliers
# 1989: 823 outliers
# 1990: 819 outliers
# 1991: 817 outliers
# 1992: 821 outliers
# 1993: 809 outliers
# 1994: 826 outliers
# 1995: 825 outliers
# 1996: 827 outliers
# 1997: 832 outliers
# 1998: 821 outliers
# 1999: 826 outliers
# 2000: 820 outliers
# 2001: 821 outliers
# 2002: 818 outliers
# 2003: 815 outliers
# 2004: 828 outliers
# 2005: 820 outliers
# 2006: 806 outliers
# 2007: 804 outliers
# 2008: 803 outliers
# 2009: 802 outliers
# 2010: 805 outliers
# 2011: 803 outliers
# 2012: 796 outliers
# 2013: 795 outliers
# 2014: 794 outliers
# 2015: 786 outliers
# 2016: 790 outliers
# 2017: 795 outliers
# 2018: 791 outliers
# 2019: 780 outliers
# 2020: 776 outliers
# 2021: 785 outliers
# 2022: 780 outliers
#
# Outliers removed from the dataset.
#
# Cleaned data shape: (447, 57)
# Cleaned data saved to /Users/ging/Documents/Data Analytics Course/GHG Emissions Worldwide/02 Data/Prepared Data/GHG_Emissions_World_Sector_Country_Cleaned.xlsx
#
# Summary Statistics:
#       count      mean       std           min       25%       50%       75%  \
# 1970  447.0  0.000187  0.000645  0.000000e+00  0.000003  0.000027  0.000149
# 1971  447.0  0.000188  0.000645  0.000000e+00  0.000003  0.000027  0.000149
# 1972  447.0  0.000183  0.000626  0.000000e+00  0.000004  0.000028  0.000156
# 1973  447.0  0.000194  0.000671  0.000000e+00  0.000004  0.000034  0.000162
# 1974  447.0  0.000194  0.000640  0.000000e+00  0.000005  0.000036  0.000164
# 1975  447.0  0.000183  0.000506  0.000000e+00  0.000005  0.000035  0.000171
# 1976  447.0  0.000184  0.000526  0.000000e+00  0.000009  0.000042  0.000169
# 1977  447.0  0.000193  0.000541  0.000000e+00  0.000010  0.000045  0.000175
# 1978  447.0  0.000180  0.000410  0.000000e+00  0.000010  0.000044  0.000181
# 1979  447.0  0.000188  0.000428  0.000000e+00  0.000010  0.000047  0.000190
# 1980  447.0  0.000186  0.000404  1.622901e-08  0.000012  0.000052  0.000199
# 1981  447.0  0.000179  0.000325  1.626224e-08  0.000014  0.000054  0.000202
# 1982  447.0  0.000177  0.000312  7.965633e-09  0.000014  0.000051  0.000203
# 1983  447.0  0.000173  0.000298  8.164511e-09  0.000014  0.000055  0.000207
# 1984  447.0  0.000178  0.000292  6.485924e-09  0.000014  0.000057  0.000221
# 1985  447.0  0.000180  0.000286  7.200298e-09  0.000016  0.000058  0.000229
# 1986  447.0  0.000188  0.000297  4.118163e-09  0.000015  0.000063  0.000223
# 1987  447.0  0.000199  0.000296  5.818008e-09  0.000017  0.000072  0.000254
# 1988  447.0  0.000202  0.000289  6.237277e-09  0.000020  0.000077  0.000259
# 1989  447.0  0.000204  0.000284  7.038745e-09  0.000019  0.000075  0.000277
# 1990  447.0  0.000226  0.000291  1.014012e-08  0.000025  0.000105  0.000319
# 1991  447.0  0.000231  0.000294  1.053536e-08  0.000026  0.000106  0.000317
# 1992  447.0  0.000233  0.000289  1.563500e-08  0.000025  0.000111  0.000344
# 1993  447.0  0.000237  0.000293  3.908750e-08  0.000028  0.000111  0.000361
# 1994  447.0  0.000247  0.000307  1.563500e-08  0.000031  0.000117  0.000369
# 1995  447.0  0.000252  0.000305  1.563500e-08  0.000032  0.000121  0.000382
# 1996  447.0  0.000254  0.000306  1.563500e-08  0.000031  0.000127  0.000393
# 1997  447.0  0.000267  0.000316  1.563500e-08  0.000033  0.000130  0.000409
# 1998  447.0  0.000273  0.000330  1.563500e-08  0.000035  0.000136  0.000418
